# %%
import pygame
import sys
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.13.5)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
row=2
col=2
moves=[]

# %%
def get_rook_moves(row, col):
        moves=list()
        for i in range(8):
            moves.append([row,i])
        for j in range(8):
            moves.append([j,col])
        print(moves)

# %%
get_rook_moves(row,col)
# Out:
# [[2, 0], [2, 1], [2, 2], [2, 3], [2, 4], [2, 5], [2, 6], [2, 7], [0, 2], [1, 2], [2, 2], [3, 2], [4, 2], [5, 2], [6, 2], [7, 2]]
